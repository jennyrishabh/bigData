# %%
pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.4 MB 43 kB/s
# ...
#      |████████████████████████████████| 199 kB 52.0 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845514 sha256=d367a3f317c0cbabe289c3581cd22bcf22428f1ebfaa333fb43aa2be78534e68
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# ...

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

source = 'https://blobstorage2401.blob.core.windows.net/raw/sales_data.csv?sp=r&st=2022-11-19T11:37:32Z&se=2022-11-21T19:37:32Z&sv=2021-06-08&sr=b&sig=qams4ABGsYjHVbdgVeh8dS3cgbwRRHasGTmw9LfjQjc%3D'
#df = pd.read_csv(source)
df=pd.read_csv(source, sep=',', encoding="ISO-8859-1")
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.appName("MyApp1").getOrCreate()

# %%
schema1 = StructType([
	StructField("ORDERNUMBER",IntegerType(),True),
	StructField("QUANTITYORDERED",IntegerType(),True),
	StructField("PRICEEACH",FloatType(),True),
	StructField("ORDERLINENUMBER",IntegerType(),True),
	StructField("SALES",FloatType(),True),
	StructField("ORDERDATE",StringType(),True),
	StructField("STATUS",StringType(),True),
	StructField("QTR_ID",IntegerType(),True),
	StructField("MONTH_ID",IntegerType(),True),
	StructField("YEAR_ID",IntegerType(),True),
	StructField("PRODUCTLINE",StringType(),True),
	StructField("MSRP",IntegerType(),True),
	StructField("PRODUCTCODE",StringType(),True),
	StructField("CUSTOMERNAME",StringType(),True),
	StructField("PHONE",StringType(),True),
	StructField("ADDRESSLINE1",StringType(),True),
	StructField("ADDRESSLINE2",StringType(),True),
	StructField("CITY",StringType(),True),
	StructField("STATE",StringType(),True),
	StructField("POSTALCODE",StringType(),True),
	StructField("COUNTRY",StringType(),True),
	StructField("TERRITORY",StringType(),True),
	StructField("CONTACTLASTNAME",StringType(),True),
	StructField("CONTACTFIRSTNAME",StringType(),True),
	StructField("DEALSIZE",StringType(),True)
])

# %%
df2=spark.createDataFrame(df, schema=schema1)

# %% [markdown]
# ## **1. df2 is the pySpark DataFrame**

# %%
df2.count()
# Out:
# 2823

# %%
df2.show()
# Out:
# +-----------+---------------+---------+---------------+-------+---------------+-------+------+--------+-------+-----------+----+-----------+--------------------+----------------+--------------------+------------+-------------+--------+----------+---------+---------+---------------+----------------+--------+
# |ORDERNUMBER|QUANTITYORDERED|PRICEEACH|ORDERLINENUMBER|  SALES|      ORDERDATE| STATUS|QTR_ID|MONTH_ID|YEAR_ID|PRODUCTLINE|MSRP|PRODUCTCODE|        CUSTOMERNAME|           PHONE|        ADDRESSLINE1|ADDRESSLINE2|         CITY|   STATE|POSTALCODE|  COUNTRY|TERRITORY|CONTACTLASTNAME|CONTACTFIRSTNAME|DEALSIZE|
# +-----------+---------------+---------+---------------+-------+---------------+-------+------+--------+-------+-----------+----+-----------+--------------------+----------------+--------------------+------------+-------------+--------+----------+---------+---------+---------------+----------------+--------+
# ...

# %%
display(df2)
# Out:
# DataFrame[ORDERNUMBER: int, QUANTITYORDERED: int, PRICEEACH: float, ORDERLINENUMBER: int, SALES: float, ORDERDATE: string, STATUS: string, QTR_ID: int, MONTH_ID: int, YEAR_ID: int, PRODUCTLINE: string, MSRP: int, PRODUCTCODE: string, CUSTOMERNAME: string, PHONE: string, ADDRESSLINE1: string, ADDRESSLINE2: string, CITY: string, STATE: string, POSTALCODE: string, COUNTRY: string, TERRITORY: string, CONTACTLASTNAME: string, CONTACTFIRSTNAME: string, DEALSIZE: string]

# %% [markdown]
# # **2. STATS OF THE GIVEN DATA**

# %%
df2.describe().show()
# Out:
# +-------+------------------+-----------------+-----------------+-----------------+------------------+--------------+---------+------------------+------------------+------------------+------------+------------------+-----------+-----------------+--------------------+--------------------+------------+------------+--------+----------+---------+---------+---------------+----------------+--------+
# |summary|       ORDERNUMBER|  QUANTITYORDERED|        PRICEEACH|  ORDERLINENUMBER|             SALES|     ORDERDATE|   STATUS|            QTR_ID|          MONTH_ID|           YEAR_ID| PRODUCTLINE|              MSRP|PRODUCTCODE|     CUSTOMERNAME|               PHONE|        ADDRESSLINE1|ADDRESSLINE2|        CITY|   STATE|POSTALCODE|  COUNTRY|TERRITORY|CONTACTLASTNAME|CONTACTFIRSTNAME|DEALSIZE|
# ...

# %% [markdown]
# # **3. TO CHECK TYPE OF DATAFRAME**

# %%
type(df2)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df2.collect()
# Out:
# [Row(ORDERNUMBER='10107', QUANTITYORDERED='30', PRICEEACH='95.7', ORDERLINENUMBER='2', SALES='2871.0', ORDERDATE='2/24/2003 0:00', STATUS='Shipped', QTR_ID='1', MONTH_ID='2', YEAR_ID='2003', PRODUCTLINE='Motorcycles', MSRP='95', PRODUCTCODE='S10_1678', CUSTOMERNAME='Land of Toys Inc.', PHONE='2125557818', ADDRESSLINE1='897 Long Airport Avenue', ADDRESSLINE2='nan', CITY='NYC', STATE='NY', POSTALCODE='10022', COUNTRY='USA', TERRITORY='nan', CONTACTLASTNAME='Yu', CONTACTFIRSTNAME='Kwai', DEALSIZE='Small'),
# ...

# %% [markdown]
# # **4. TOTAL NO. OF SALES GROUPED BY COUNTRY**

# %%
df2.groupby('COUNTRY').sum('SALES').show()
# Out:
# +-----------+------------------+
# |    COUNTRY|        sum(SALES)|
# +-----------+------------------+
# |     Sweden|210014.21020507812|
# |Philippines|    94015.73046875|
# |  Singapore| 288488.4102783203|
# |    Germany| 220472.0897216797|
# |     France|1110916.5217895508|
# |    Belgium|108412.61962890625|
# |    Finland|329581.91033935547|
# |      Italy| 374674.3109741211|
# |     Norway|307463.69970703125|
# |      Spain|1215686.9223632812|
# |    Denmark|245637.15063476562|
# |    Ireland| 57756.43029785156|
# |        USA| 3627982.825744629|
# |         UK|478880.45892333984|
# |Switzerland|   117713.55859375|
# |     Canada|224078.55993652344|
# |      Japan|188167.81060791016|
# |  Australia| 630623.0987548828|
# |    Austria|202062.53033447266|
# +-----------+------------------+

# %% [markdown]
# # **5. TOTAL NO. OF QUANTITY ORDERED GROUPED BY COUNTRY**

# %%
df2.groupby('COUNTRY').sum('QUANTITYORDERED').show()
# Out:
# +-----------+--------------------+
# |    COUNTRY|sum(QUANTITYORDERED)|
# +-----------+--------------------+
# |     Sweden|                2006|
# |Philippines|                 961|
# |  Singapore|                2760|
# |    Germany|                2148|
# |     France|               11090|
# |    Belgium|                1074|
# |    Finland|                3192|
# |      Italy|                3773|
# |     Norway|                2842|
# |      Spain|               12429|
# |    Denmark|                2197|
# |    Ireland|                 490|
# |        USA|               35659|
# |         UK|                5013|
# |Switzerland|                1078|
# |     Canada|                2293|
# |      Japan|                1842|
# |  Australia|                6246|
# |    Austria|                1974|
# +-----------+--------------------+

# %% [markdown]
# # **6. TOTAL NO. OF QUANTITY ORDERED GROUPED BY COUNTRY**

# %%
df2.groupby('COUNTRY','CITY').sum('SALES').show()
# Out:
# +-----------+--------------+------------------+
# |    COUNTRY|          CITY|        sum(SALES)|
# +-----------+--------------+------------------+
# |    Belgium|     Charleroi|33440.100341796875|
# |        USA|        Newark| 83228.18920898438|
# |  Australia|     Chatswood|151570.97985839844|
# |    Austria|      Salzburg|149798.63018798828|
# |         UK|        London|124823.53979492188|
# |        USA|        Nashua|131685.29949951172|
# |Philippines|   Makati City|    94015.73046875|
# |        USA|        Boston|154069.66052246094|
# |  Australia|South Brisbane|  59469.1201171875|
# |        USA|     San Diego| 87489.23010253906|
# |      Italy|       Bergamo| 137955.7201538086|
# |         UK|    Manchester|157807.80963134766|
# |      Japan|         Osaka|     67605.0703125|
# |        USA|      San Jose|160010.27026367188|
# |        USA| San Francisco| 224358.6805419922|
# |  Australia|  Glen Waverly| 64591.45947265625|
# |        USA|     Allentown|122138.13995361328|
# ...

# %% [markdown]
# # **7. TOTAL SALES PER YEAR**

# %%
df2.groupby('YEAR_ID').sum('SALES').show()
# Out:
# +-------+------------------+
# |YEAR_ID|        sum(SALES)|
# +-------+------------------+
# |   2003| 3516979.547241211|
# |   2004| 4724162.593383789|
# |   2005|1791486.7086791992|
# +-------+------------------+

# %% [markdown]
# # **8. AVERAGE BASED ON ALL THE COUNTRY'S**

# %%
df2.groupby('COUNTRY').mean().show()
# Out:
# +-----------+------------------+--------------------+-----------------+--------------------+------------------+------------------+------------------+------------------+------------------+
# |    COUNTRY|  avg(ORDERNUMBER)|avg(QUANTITYORDERED)|   avg(PRICEEACH)|avg(ORDERLINENUMBER)|        avg(SALES)|       avg(QTR_ID)|     avg(MONTH_ID)|      avg(YEAR_ID)|         avg(MSRP)|
# +-----------+------------------+--------------------+-----------------+--------------------+------------------+------------------+------------------+------------------+------------------+
# |     Sweden|10274.421052631578|   35.19298245614035|86.72824565151282|   5.912280701754386|3684.4598281592653|3.2280701754385963| 8.824561403508772|2003.8245614035088|104.78947368421052|
# |Philippines|10162.923076923076|   36.96153846153846|82.49961471557617|   6.423076923076923|3615.9896334134614|2.1538461538461537| 6.076923076923077|2003.1538461538462| 97.96153846153847|
# ...

# %% [markdown]
# # **9. ORDER BY SALES ASCENDING**

# %%
df2.orderBy("SALES").show()
# Out:
# +-----------+---------------+---------+---------------+------+---------------+----------+------+--------+-------+----------------+----+-----------+--------------------+---------------+--------------------+------------+------------+--------+----------+---------+---------+---------------+----------------+--------+
# |ORDERNUMBER|QUANTITYORDERED|PRICEEACH|ORDERLINENUMBER| SALES|      ORDERDATE|    STATUS|QTR_ID|MONTH_ID|YEAR_ID|     PRODUCTLINE|MSRP|PRODUCTCODE|        CUSTOMERNAME|          PHONE|        ADDRESSLINE1|ADDRESSLINE2|        CITY|   STATE|POSTALCODE|  COUNTRY|TERRITORY|CONTACTLASTNAME|CONTACTFIRSTNAME|DEALSIZE|
# +-----------+---------------+---------+---------------+------+---------------+----------+------+--------+-------+----------------+----+-----------+--------------------+---------------+--------------------+------------+------------+--------+----------+---------+---------+---------------+----------------+--------+
# ...

# %% [markdown]
# # **10. ORDER BY SALES DESCENDING**

# %%
df2.orderBy(df2["SALES"].desc()).show()
# Out:
# +-----------+---------------+---------+---------------+-------+---------------+----------+------+--------+-------+------------+----+-----------+--------------------+----------------+--------------------+------------+-------------+--------+----------+---------+---------+---------------+----------------+--------+
# |ORDERNUMBER|QUANTITYORDERED|PRICEEACH|ORDERLINENUMBER|  SALES|      ORDERDATE|    STATUS|QTR_ID|MONTH_ID|YEAR_ID| PRODUCTLINE|MSRP|PRODUCTCODE|        CUSTOMERNAME|           PHONE|        ADDRESSLINE1|ADDRESSLINE2|         CITY|   STATE|POSTALCODE|  COUNTRY|TERRITORY|CONTACTLASTNAME|CONTACTFIRSTNAME|DEALSIZE|
# +-----------+---------------+---------+---------------+-------+---------------+----------+------+--------+-------+------------+----+-----------+--------------------+----------------+--------------------+------------+-------------+--------+----------+---------+---------+---------------+----------------+--------+
# ...

# %% [markdown]
# # **11. SUM BY AGGREGATE**

# %%
group_data = df2.groupBy("COUNTRY")
group_data.agg({'SALES':'sum'}).show()
# Out:
# +-----------+------------------+
# |    COUNTRY|        sum(SALES)|
# +-----------+------------------+
# |     Sweden|210014.21020507812|
# |Philippines|    94015.73046875|
# |  Singapore| 288488.4102783203|
# |    Germany| 220472.0897216797|
# |     France|1110916.5217895508|
# |    Belgium|108412.61962890625|
# |    Finland|329581.91033935547|
# |      Italy| 374674.3109741211|
# |     Norway|307463.69970703125|
# |      Spain|1215686.9223632812|
# |    Denmark|245637.15063476562|
# |    Ireland| 57756.43029785156|
# |        USA| 3627982.825744629|
# |         UK|478880.45892333984|
# |Switzerland|   117713.55859375|
# |     Canada|224078.55993652344|
# |      Japan|188167.81060791016|
# |  Australia| 630623.0987548828|
# |    Austria|202062.53033447266|
# +-----------+------------------+

# %% [markdown]
# # **12. MAX.BY AGGREGATE**

# %%
group_data.agg({'SALES':'max'}).show()
# Out:
# +-----------+----------+
# |    COUNTRY|max(SALES)|
# +-----------+----------+
# |     Sweden|   7209.11|
# |Philippines|   7483.98|
# |  Singapore|   10993.5|
# |    Germany|   8940.96|
# |     France|   11739.7|
# |    Belgium|   6804.63|
# |    Finland|   10606.2|
# |      Italy|   9160.36|
# |     Norway|   8844.12|
# |      Spain|   12001.0|
# |    Denmark|   10468.9|
# |    Ireland|    8258.0|
# |        USA|   14082.8|
# |         UK|   11886.6|
# |Switzerland|    6761.6|
# |     Canada|   9064.89|
# |      Japan|   10758.0|
# |  Australia|   9774.03|
# |    Austria|    9240.0|
# +-----------+----------+

# %% [markdown]
# # **13. TOTAL SALES USING AGGREGATE**

# %%
df2.agg({'SALES':'sum'}).show()
# Out:
# +------------------+
# |        sum(SALES)|
# +------------------+
# |1.00326288493042E7|
# +------------------+

# %% [markdown]
# # **14. CHANGE NAME OF COLUMNS WITH ALIAS**

# %%
from pyspark.sql.functions import countDistinct
df2.select(countDistinct("PRICEEACH").alias("Distinct Price")).show()
# Out:
# +--------------+
# |Distinct Price|
# +--------------+
# |          1016|
# +--------------+

# %% [markdown]
# # **15. MIN. SALES USING GROUPBY AND AGGREGATE**

# %%
df2.groupby('COUNTRY').agg({'SALES': 'MIN'}).show()
# Out:
# +-----------+----------+
# |    COUNTRY|min(SALES)|
# +-----------+----------+
# |     Sweden|   1467.48|
# |Philippines|   1173.15|
# |  Singapore|    785.64|
# |    Germany|    948.99|
# |     France|    482.13|
# |    Belgium|     881.4|
# |    Finland|    891.03|
# |      Italy|     577.6|
# |     Norway|   1129.04|
# |      Spain|     683.8|
# |    Denmark|    1146.5|
# |    Ireland|    1056.4|
# |        USA|    541.14|
# |         UK|     710.2|
# |Switzerland|   1205.04|
# |     Canada|   1119.93|
# |      Japan|    553.95|
# |  Australia|    652.35|
# |    Austria|    640.05|
# +-----------+----------+
